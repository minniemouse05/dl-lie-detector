# %% [markdown]
# <a href="https://colab.research.google.com/github/cching3/lie-detector/blob/main/deep_learning_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Real-life_Deception_Detection_2016/Annotation"
# Out:
# 'All_Gestures_Deceptive and Truthful.csv'

# %%
data_dir = "/content/drive/MyDrive/Real-life_Deception_Detection_2016"

# %%
df = pd.read_csv(f"{data_dir}/Annotation/All_Gestures_Deceptive and Truthful.csv")
df
# Out:
#                       id  OtherGestures  Smile  Laugh  Scowl  \
# 0      trial_lie_001.mp4              1      0      0      0
# 1      trial_lie_002.mp4              1      0      0      0
# 2      trial_lie_003.mp4              1      0      0      0
# 3      trial_lie_004.mp4              1      0      0      0
# 4      trial_lie_005.mp4              1      0      0      0
# ..                   ...            ...    ...    ...    ...
# 116  trial_truth_056.mp4              1      0      0      0
# 117  trial_truth_057.mp4              1      0      0      0
# 118  trial_truth_058.mp4              1      0      0      0
# 119  trial_truth_059.mp4              0      0      0      1
# 120  trial_truth_060.mp4              0      1      0      0
#
#      otherEyebrowMovement  Frown  Raise  OtherEyeMovements  Close-R  ...  \
# 0                       1      0      0                  1        0  ...
# 1                       0      1      0                  1        0  ...
# ...
